# %%
import Corpus as corpus
import math
import os
from nltk.stem.wordnet import WordNetLemmatizer
import pickle
import spacy
import nltk
from nltk.corpus import wordnet as wn
from spacy.lang.en import English
import pandas as pd
import gensim
from gensim import corpora
from gensim.corpora import Dictionary
from multiprocessing import Process, Queue
import time
import numpy as np
from IPython import display
parser = English()

#nltk.download('popular')
#nltk.download('wordnet')
#nltk.download('stopwords')
#spacy.load('en_core_web_md')

def doubledecode(word,convertdate, as_unicode=True):
    try:
        if word is not None:
            # remove the windows gremlins O^1
            if '&aposs' in word:
                word = word.replace('&aposs', "")
            for src, dest in cp1252.items():
                word = word.replace(src, dest)
            word = word.encode('raw_unicode_escape')
            if as_unicode:
                # return as unicode string
                word = word.decode('utf8', 'ignore')
            if convertdate is True:
                word = word.replace('-','')
            else:
                word = word.strip().lower()
            if 'reuters.' in word:
                word = word.replace('reuters.', "")
            if 'bloomberg' in word:
                word = word.replace('bloomberg', "")
            if 'investorplace' in word:
                word = word.replace('investorplace', "")
            if 'frankfurt' in word:
                word = word.replace('frankfurt', "")
            if 'investing.com' in word:
                word = word.replace('investing.com', "")
            if 'reuters' in word:
                word = word.replace('reuters', "")
            if 'new york (reuters)' in word:
                word = word.replace('new york (reuters)', "")
            return word
    except Exception:
        print word

cp1252 = {
    u"\u0000": u"\x00",  # NULL
    u"\u0001": u"\x01",  # START OF HEADING
    u"\u0002": u"\x02",  # START OF TEXT
    u"\u0003": u"\x03",  # END OF TEXT
    u"\u0004": u"\x04",  # END OF TRANSMISSION
    u"\u0005": u"\x05",  # ENQUIRY
    u"\u0006": u"\x06",  # ACKNOWLEDGE
    u"\u0007": u"\x07",  # BELL
    u"\u0008": u"\x08",  # BACKSPACE
    u"\u0009": u"\x09",  # HORIZONTAL TABULATION
    u"\u000A": u"\x0A",  # LINE FEED
    u"\u000B": u"\x0B",  # VERTICAL TABULATION
    u"\u000C": u"\x0C",  # FORM FEED
    u"\u000D": u"\x0D",  # CARRIAGE RETURN
    u"\u000E": u"\x0E",  # SHIFT OUT
    u"\u000F": u"\x0F",  # SHIFT IN
    u"\u0010": u"\x10",  # DATA LINK ESCAPE
    u"\u0011": u"\x11",  # DEVICE CONTROL ONE
    u"\u0012": u"\x12",  # DEVICE CONTROL TWO
    u"\u0013": u"\x13",  # DEVICE CONTROL THREE
    u"\u0014": u"\x14",  # DEVICE CONTROL FOUR
    u"\u0015": u"\x15",  # NEGATIVE ACKNOWLEDGE
    u"\u0016": u"\x16",  # SYNCHRONOUS IDLE
    u"\u0017": u"\x17",  # END OF TRANSMISSION BLOCK
    u"\u0018": u"\x18",  # CANCEL
    u"\u0019": u"\x19",  # END OF MEDIUM
    u"\u001A": u"\x1A",  # SUBSTITUTE
    u"\u001B": u"\x1B",  # ESCAPE
    u"\u001C": u"\x1C",  # FILE SEPARATOR
    u"\u001D": u"\x1D",  # GROUP SEPARATOR
    u"\u001E": u"\x1E",  # RECORD SEPARATOR
    u"\u001F": u"\x1F",  # UNIT SEPARATOR
    u"\u0020": u"\x20",  # SPACE
    u"\u0021": u"\x21",  # EXCLAMATION MARK
    u"\u0022": u"\x22",  # QUOTATION MARK
    u"\u0023": u"\x23",  # NUMBER SIGN
    u"\u0024": u"\x24",  # DOLLAR SIGN
    u"\u0025": u"\x25",  # PERCENT SIGN
    u"\u0026": u"\x26",  # AMPERSAND
    u"\u0027": u"\x27",  # APOSTROPHE
    u"\u0028": u"\x28",  # LEFT PARENTHESIS
    u"\u0029": u"\x29",  # RIGHT PARENTHESIS
    u"\u002A": u"\x2A",  # ASTERISK
    u"\u002B": u"\x2B",  # PLUS SIGN
    u"\u002C": u"\x2C",  # COMMA
    u"\u002D": u"\x2D",  # HYPHEN-MINUS
    u"\u002E": u"\x2E",  # FULL STOP
    u"\u002F": u"\x2F",  # SOLIDUS
    u"\u0030": u"\x30",  # DIGIT ZERO
    u"\u0031": u"\x31",  # DIGIT ONE
    u"\u0032": u"\x32",  # DIGIT TWO
    u"\u0033": u"\x33",  # DIGIT THREE
    u"\u0034": u"\x34",  # DIGIT FOUR
    u"\u0035": u"\x35",  # DIGIT FIVE
    u"\u0036": u"\x36",  # DIGIT SIX
    u"\u0037": u"\x37",  # DIGIT SEVEN
    u"\u0038": u"\x38",  # DIGIT EIGHT
    u"\u0039": u"\x39",  # DIGIT NINE
    u"\u003A": u"\x3A",  # COLON
    u"\u003B": u"\x3B",  # SEMICOLON
    u"\u003C": u"\x3C",  # LESS-THAN SIGN
    u"\u003D": u"\x3D",  # EQUALS SIGN
    u"\u003E": u"\x3E",  # GREATER-THAN SIGN
    u"\u003F": u"\x3F",  # QUESTION MARK
    u"\u0040": u"\x40",  # COMMERCIAL AT
    u"\u0041": u"\x41",  # LATIN CAPITAL LETTER A
    u"\u0042": u"\x42",  # LATIN CAPITAL LETTER B
    u"\u0043": u"\x43",  # LATIN CAPITAL LETTER C
    u"\u0044": u"\x44",  # LATIN CAPITAL LETTER D
    u"\u0045": u"\x45",  # LATIN CAPITAL LETTER E
    u"\u0046": u"\x46",  # LATIN CAPITAL LETTER F
    u"\u0047": u"\x47",  # LATIN CAPITAL LETTER G
    u"\u0048": u"\x48",  # LATIN CAPITAL LETTER H
    u"\u0049": u"\x49",  # LATIN CAPITAL LETTER I
    u"\u004A": u"\x4A",  # LATIN CAPITAL LETTER J
    u"\u004B": u"\x4B",  # LATIN CAPITAL LETTER K
    u"\u004C": u"\x4C",  # LATIN CAPITAL LETTER L
    u"\u004D": u"\x4D",  # LATIN CAPITAL LETTER M
    u"\u004E": u"\x4E",  # LATIN CAPITAL LETTER N
    u"\u004F": u"\x4F",  # LATIN CAPITAL LETTER O
    u"\u0050": u"\x50",  # LATIN CAPITAL LETTER P
    u"\u0051": u"\x51",  # LATIN CAPITAL LETTER Q
    u"\u0052": u"\x52",  # LATIN CAPITAL LETTER R
    u"\u0053": u"\x53",  # LATIN CAPITAL LETTER S
    u"\u0054": u"\x54",  # LATIN CAPITAL LETTER T
    u"\u0055": u"\x55",  # LATIN CAPITAL LETTER U
    u"\u0056": u"\x56",  # LATIN CAPITAL LETTER V
    u"\u0057": u"\x57",  # LATIN CAPITAL LETTER W
    u"\u0058": u"\x58",  # LATIN CAPITAL LETTER X
    u"\u0059": u"\x59",  # LATIN CAPITAL LETTER Y
    u"\u005A": u"\x5A",  # LATIN CAPITAL LETTER Z
    u"\u005B": u"\x5B",  # LEFT SQUARE BRACKET
    u"\u005C": u"\x5C",  # REVERSE SOLIDUS
    u"\u005D": u"\x5D",  # RIGHT SQUARE BRACKET
    u"\u005E": u"\x5E",  # CIRCUMFLEX ACCENT
    u"\u005F": u"\x5F",  # LOW LINE
    u"\u0060": u"\x60",  # GRAVE ACCENT
    u"\u0061": u"\x61",  # LATIN SMALL LETTER A
    u"\u0062": u"\x62",  # LATIN SMALL LETTER B
    u"\u0063": u"\x63",  # LATIN SMALL LETTER C
    u"\u0064": u"\x64",  # LATIN SMALL LETTER D
    u"\u0065": u"\x65",  # LATIN SMALL LETTER E
    u"\u0066": u"\x66",  # LATIN SMALL LETTER F
    u"\u0067": u"\x67",  # LATIN SMALL LETTER G
    u"\u0068": u"\x68",  # LATIN SMALL LETTER H
    u"\u0069": u"\x69",  # LATIN SMALL LETTER I
    u"\u006A": u"\x6A",  # LATIN SMALL LETTER J
    u"\u006B": u"\x6B",  # LATIN SMALL LETTER K
    u"\u006C": u"\x6C",  # LATIN SMALL LETTER L
    u"\u006D": u"\x6D",  # LATIN SMALL LETTER M
    u"\u006E": u"\x6E",  # LATIN SMALL LETTER N
    u"\u006F": u"\x6F",  # LATIN SMALL LETTER O
    u"\u0070": u"\x70",  # LATIN SMALL LETTER P
    u"\u0071": u"\x71",  # LATIN SMALL LETTER Q
    u"\u0072": u"\x72",  # LATIN SMALL LETTER R
    u"\u0073": u"\x73",  # LATIN SMALL LETTER S
    u"\u0074": u"\x74",  # LATIN SMALL LETTER T
    u"\u0075": u"\x75",  # LATIN SMALL LETTER U
    u"\u0076": u"\x76",  # LATIN SMALL LETTER V
    u"\u0077": u"\x77",  # LATIN SMALL LETTER W
    u"\u0078": u"\x78",  # LATIN SMALL LETTER X
    u"\u0079": u"\x79",  # LATIN SMALL LETTER Y
    u"\u007A": u"\x7A",  # LATIN SMALL LETTER Z
    u"\u007B": u"\x7B",  # LEFT CURLY BRACKET
    u"\u007C": u"\x7C",  # VERTICAL LINE
    u"\u007D": u"\x7D",  # RIGHT CURLY BRACKET
    u"\u007E": u"\x7E",  # TILDE
    u"\u007F": u"\x7F",  # DELETE
    u"\u20AC": u"\x80",  # EURO SIGN
    u"\u201A": u"\x82",  # SINGLE LOW-9 QUOTATION MARK
    u"\u0192": u"\x83",  # LATIN SMALL LETTER F WITH HOOK
    u"\u201E": u"\x84",  # DOUBLE LOW-9 QUOTATION MARK
    u"\u2026": u"\x85",  # HORIZONTAL ELLIPSIS
    u"\u2020": u"\x86",  # DAGGER
    u"\u2021": u"\x87",  # DOUBLE DAGGER
    u"\u02C6": u"\x88",  # MODIFIER LETTER CIRCUMFLEX ACCENT
    u"\u2030": u"\x89",  # PER MILLE SIGN
    u"\u0160": u"\x8A",  # LATIN CAPITAL LETTER S WITH CARON
    u"\u2039": u"\x8B",  # SINGLE LEFT-POINTING ANGLE QUOTATION MARK
    u"\u0152": u"\x8C",  # LATIN CAPITAL LIGATURE OE
    u"\u017D": u"\x8E",  # LATIN CAPITAL LETTER Z WITH CARON
    u"\u2018": u"\x91",  # LEFT SINGLE QUOTATION MARK
    u"\u2019": u"\x92",  # RIGHT SINGLE QUOTATION MARK
    u"\u201C": u"\x93",  # LEFT DOUBLE QUOTATION MARK
    u"\u201D": u"\x94",  # RIGHT DOUBLE QUOTATION MARK
    u"\u2022": u"\x95",  # BULLET
    u"\u2013": u"\x96",  # EN DASH
    u"\u2014": u"\x97",  # EM DASH
    u"\u02DC": u"\x98",  # SMALL TILDE
    u"\u2122": u"\x99",  # TRADE MARK SIGN
    u"\u0161": u"\x9A",  # LATIN SMALL LETTER S WITH CARON
    u"\u203A": u"\x9B",  # SINGLE RIGHT-POINTING ANGLE QUOTATION MARK
    u"\u0153": u"\x9C",  # LATIN SMALL LIGATURE OE
    u"\u017E": u"\x9E",  # LATIN SMALL LETTER Z WITH CARON
    u"\u0178": u"\x9F",  # LATIN CAPITAL LETTER Y WITH DIAERESIS
    u"\u00A0": u"\xA0",  # NO-BREAK SPACE
    u"\u00A1": u"\xA1",  # INVERTED EXCLAMATION MARK
    u"\u00A2": u"\xA2",  # CENT SIGN
    u"\u00A3": u"\xA3",  # POUND SIGN
    u"\u00A4": u"\xA4",  # CURRENCY SIGN
    u"\u00A5": u"\xA5",  # YEN SIGN
    u"\u00A6": u"\xA6",  # BROKEN BAR
    u"\u00A7": u"\xA7",  # SECTION SIGN
    u"\u00A8": u"\xA8",  # DIAERESIS
    u"\u00A9": u"\xA9",  # COPYRIGHT SIGN
    u"\u00AA": u"\xAA",  # FEMININE ORDINAL INDICATOR
    u"\u00AB": u"\xAB",  # LEFT-POINTING DOUBLE ANGLE QUOTATION MARK
    u"\u00AC": u"\xAC",  # NOT SIGN
    u"\u00AD": u"\xAD",  # SOFT HYPHEN
    u"\u00AE": u"\xAE",  # REGISTERED SIGN
    u"\u00AF": u"\xAF",  # MACRON
    u"\u00B0": u"\xB0",  # DEGREE SIGN
    u"\u00B1": u"\xB1",  # PLUS-MINUS SIGN
    u"\u00B2": u"\xB2",  # SUPERSCRIPT TWO
    u"\u00B3": u"\xB3",  # SUPERSCRIPT THREE
    u"\u00B4": u"\xB4",  # ACUTE ACCENT
    u"\u00B5": u"\xB5",  # MICRO SIGN
    u"\u00B6": u"\xB6",  # PILCROW SIGN
    u"\u00B7": u"\xB7",  # MIDDLE DOT
    u"\u00B8": u"\xB8",  # CEDILLA
    u"\u00B9": u"\xB9",  # SUPERSCRIPT ONE
    u"\u00BA": u"\xBA",  # MASCULINE ORDINAL INDICATOR
    u"\u00BB": u"\xBB",  # RIGHT-POINTING DOUBLE ANGLE QUOTATION MARK
    u"\u00BC": u"\xBC",  # VULGAR FRACTION ONE QUARTER
    u"\u00BD": u"\xBD",  # VULGAR FRACTION ONE HALF
    u"\u00BE": u"\xBE",  # VULGAR FRACTION THREE QUARTERS
    u"\u00BF": u"\xBF",  # INVERTED QUESTION MARK
    u"\u00C0": u"\xC0",  # LATIN CAPITAL LETTER A WITH GRAVE
    u"\u00C1": u"\xC1",  # LATIN CAPITAL LETTER A WITH ACUTE
    u"\u00C2": u"\xC2",  # LATIN CAPITAL LETTER A WITH CIRCUMFLEX
    u"\u00C3": u"\xC3",  # LATIN CAPITAL LETTER A WITH TILDE
    u"\u00C4": u"\xC4",  # LATIN CAPITAL LETTER A WITH DIAERESIS
    u"\u00C5": u"\xC5",  # LATIN CAPITAL LETTER A WITH RING ABOVE
    u"\u00C6": u"\xC6",  # LATIN CAPITAL LETTER AE
    u"\u00C7": u"\xC7",  # LATIN CAPITAL LETTER C WITH CEDILLA
    u"\u00C8": u"\xC8",  # LATIN CAPITAL LETTER E WITH GRAVE
    u"\u00C9": u"\xC9",  # LATIN CAPITAL LETTER E WITH ACUTE
    u"\u00CA": u"\xCA",  # LATIN CAPITAL LETTER E WITH CIRCUMFLEX
    u"\u00CB": u"\xCB",  # LATIN CAPITAL LETTER E WITH DIAERESIS
    u"\u00CC": u"\xCC",  # LATIN CAPITAL LETTER I WITH GRAVE
    u"\u00CD": u"\xCD",  # LATIN CAPITAL LETTER I WITH ACUTE
    u"\u00CE": u"\xCE",  # LATIN CAPITAL LETTER I WITH CIRCUMFLEX
    u"\u00CF": u"\xCF",  # LATIN CAPITAL LETTER I WITH DIAERESIS
    u"\u00D0": u"\xD0",  # LATIN CAPITAL LETTER ETH
    u"\u00D1": u"\xD1",  # LATIN CAPITAL LETTER N WITH TILDE
    u"\u00D2": u"\xD2",  # LATIN CAPITAL LETTER O WITH GRAVE
    u"\u00D3": u"\xD3",  # LATIN CAPITAL LETTER O WITH ACUTE
    u"\u00D4": u"\xD4",  # LATIN CAPITAL LETTER O WITH CIRCUMFLEX
    u"\u00D5": u"\xD5",  # LATIN CAPITAL LETTER O WITH TILDE
    u"\u00D6": u"\xD6",  # LATIN CAPITAL LETTER O WITH DIAERESIS
    u"\u00D7": u"\xD7",  # MULTIPLICATION SIGN
    u"\u00D8": u"\xD8",  # LATIN CAPITAL LETTER O WITH STROKE
    u"\u00D9": u"\xD9",  # LATIN CAPITAL LETTER U WITH GRAVE
    u"\u00DA": u"\xDA",  # LATIN CAPITAL LETTER U WITH ACUTE
    u"\u00DB": u"\xDB",  # LATIN CAPITAL LETTER U WITH CIRCUMFLEX
    u"\u00DC": u"\xDC",  # LATIN CAPITAL LETTER U WITH DIAERESIS
    u"\u00DD": u"\xDD",  # LATIN CAPITAL LETTER Y WITH ACUTE
    u"\u00DE": u"\xDE",  # LATIN CAPITAL LETTER THORN
    u"\u00DF": u"\xDF",  # LATIN SMALL LETTER SHARP S
    u"\u00E0": u"\xE0",  # LATIN SMALL LETTER A WITH GRAVE
    u"\u00E1": u"\xE1",  # LATIN SMALL LETTER A WITH ACUTE
    u"\u00E2": u"\xE2",  # LATIN SMALL LETTER A WITH CIRCUMFLEX
    u"\u00E3": u"\xE3",  # LATIN SMALL LETTER A WITH TILDE
    u"\u00E4": u"\xE4",  # LATIN SMALL LETTER A WITH DIAERESIS
    u"\u00E5": u"\xE5",  # LATIN SMALL LETTER A WITH RING ABOVE
    u"\u00E6": u"\xE6",  # LATIN SMALL LETTER AE
    u"\u00E7": u"\xE7",  # LATIN SMALL LETTER C WITH CEDILLA
    u"\u00E8": u"\xE8",  # LATIN SMALL LETTER E WITH GRAVE
    u"\u00E9": u"\xE9",  # LATIN SMALL LETTER E WITH ACUTE
    u"\u00EA": u"\xEA",  # LATIN SMALL LETTER E WITH CIRCUMFLEX
    u"\u00EB": u"\xEB",  # LATIN SMALL LETTER E WITH DIAERESIS
    u"\u00EC": u"\xEC",  # LATIN SMALL LETTER I WITH GRAVE
    u"\u00ED": u"\xED",  # LATIN SMALL LETTER I WITH ACUTE
    u"\u00EE": u"\xEE",  # LATIN SMALL LETTER I WITH CIRCUMFLEX
    u"\u00EF": u"\xEF",  # LATIN SMALL LETTER I WITH DIAERESIS
    u"\u00F0": u"\xF0",  # LATIN SMALL LETTER ETH
    u"\u00F1": u"\xF1",  # LATIN SMALL LETTER N WITH TILDE
    u"\u00F2": u"\xF2",  # LATIN SMALL LETTER O WITH GRAVE
    u"\u00F3": u"\xF3",  # LATIN SMALL LETTER O WITH ACUTE
    u"\u00F4": u"\xF4",  # LATIN SMALL LETTER O WITH CIRCUMFLEX
    u"\u00F5": u"\xF5",  # LATIN SMALL LETTER O WITH TILDE
    u"\u00F6": u"\xF6",  # LATIN SMALL LETTER O WITH DIAERESIS
    u"\u00F7": u"\xF7",  # DIVISION SIGN
    u"\u00F8": u"\xF8",  # LATIN SMALL LETTER O WITH STROKE
    u"\u00F9": u"\xF9",  # LATIN SMALL LETTER U WITH GRAVE
    u"\u00FA": u"\xFA",  # LATIN SMALL LETTER U WITH ACUTE
    u"\u00FB": u"\xFB",  # LATIN SMALL LETTER U WITH CIRCUMFLEX
    u"\u00FC": u"\xFC",  # LATIN SMALL LETTER U WITH DIAERESIS
    u"\u00FD": u"\xFD",  # LATIN SMALL LETTER Y WITH ACUTE
    u"\u00FE": u"\xFE",  # LATIN SMALL LETTER THORN
    u"\u00FF": u"\xFF"  # LATIN SMALL LETTER Y WITH DIAERESIS
}


def tokenize(text):
    lda_tokens = []
    tokens = parser(doubledecode(text))

    for token in tokens:
        if token.orth_.isspace():
            continue
        elif token.like_url:
            lda_tokens.append('URL')
        elif token.orth_.startswith('@'):
            lda_tokens.append('SCREEN_NAME')
        else:
            lda_tokens.append(token.lower_)

    return lda_tokens


def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma


def get_lemma2(word):
    return WordNetLemmatizer().lemmatize(word)

en_stop = set(nltk.corpus.stopwords.words('english'))

def prepare_text_for_lda(text):
    if not (isinstance(text, float) and math.isnan(text)) and len(text)>0:
        tokens = tokenize(text)
        tokens = [token for token in tokens if len(token) > 4]
        tokens = [token for token in tokens if token not in en_stop]
        tokens = [get_lemma2(token) for token in tokens]
        #print(type(tokens))
        return tokens
"""apply funziona su una base riga / colonna di un DataFrame,
    applymap funziona in base agli elementi su un DataFrame
    e map funziona in base agli elementi di una serie."""
def tokenize_worker(all_news, result):
    print "Inizio ",os.getpid()
    tok = all_news.applymap(lambda row: prepare_text_for_lda(row['news']))
    result.put(tok.values)
    print "Fine ",os.getpid()
    return

if __name__ =='__main__':
    result = Queue()
    print "Inizio Lettura dati"
    t1 = time.time()

    all_news = pd.DataFrame()
    economy_news = pd.read_excel('dataset/economy-news.xlsx',na_values='null')
    economy_news = economy_news.assign(category='economy')
    stock_news = pd.read_excel("dataset/stock_market_news.xlsx",na_values='null')
    stock_news = stock_news.assign(category='stock')
    commodities_news = pd.read_excel("dataset/commodities_news.xlsx",na_values='null')
    commodities_news = commodities_news.assign(category='commodities')
    technology_news = pd.read_excel("dataset/technology_news.xlsx",na_values='null')
    technology_news = technology_news.assign(category='technology')
    frames = [economy_news, stock_news, commodities_news,technology_news]

    print "Fine lettura dati"
# Out:
# Inizio Lettura dati
# Fine lettura dati

# %%
from IPython.display import display
all_news = pd.concat(frames)
all_news = all_news.dropna()
all_news = all_news.loc[~all_news['date'].str.contains('ago')]
display(all_news)
# Out:
#                                                    title  id_page  \
# 8      Iran approves anti-money laundering bill to ea...        1
# 9      China house price gains no longer a certainty:...        1
# 10     Take Five: Be careful out there! World markets...        1
# 11     Trump threatens years-long government shutdown...        1
# 12     Fed's Mester: Rates near neutral mean Fed can ...        1
# 13     Powell tells markets Fed is flexible and aware...        1
# 14     Yield curve not reliable U.S. recession indica...        1
# 15     China's economic woes put U.S. in strong posit...        1
# 16     Trump claims trade talks with China going 'ver...        1
# 17     U.S. economic growth likely to slow in 2019: F...        1
# 18     Brazil's 'Chicago Oldies' aim to revive Pinoch...        1
# 19     Fed Chair Powell says he would not resign if a...        1
# 20     Powell Says Fed Ready to Adjust Policy If Need...        1
# 21     Traders keep bets on no U.S. Fed rate hikes in...        1
# 22     Euro zone finance ministers to choose successo...        1
# 23     UK local authority pension schemes cut hedge f...        1
# 24     China slashes banks' reserve requirements agai...        1
# 25     China warnings signal Trump's trade war finall...        1
# 26     Brazil's Bolsonaro may raise personal loan tax...        1
# 27          Top 5 Things to Know in the Market on Friday        1
# 28     China and U.S. to hold trade talks in Beijing ...        1
# 29     ECB rates to remain low as long as necessary: ...        1
# 30     China says will cut banks' reserve requirement...        1
# 31     On first day in power, House Democrats challen...        1
# 32     Two-year yield dips below key Fed rate for fir...        1
# 33     China approves new urban railway projects wort...        1
# 34     Powell's plain English Fed may need more nuanc...        1
# 35     Chances of Fed Rate Cut Jump as Slowdown Worri...        1
# 36     End of ECB buys leaves Italy, France, Spain wi...        2
# 37     Apple sales should pick up when U.S.-China str...        2
# ...                                                  ...      ...
# 23935  Netflix's Europe expansion seen eating into pr...      921
# 23936  Comcast, Lionsgate add more app content for fi...      921
# 23937  China's Xiaomi announces latest flagship Mi 4 ...      921
# 23938  Fund managers unconvinced by Apple rebound as ...      921
# 23939  Seagate, Avago subsidiary LSI do not violate R...      921
# 23940      Netflix profit more than doubles, shares rise      921
# 23941  Talk on cracking Internet anonymity service To...      921
# 23942  Italy gives Google 18 months to change data us...      921
# 23943  Ex-Autonomy CFO opposes HP shareholder settlement      921
# 23944  Payments startup Stripe launches in Australia,...      921
# 23945  Israel's Mobileye starts road show for $500 mi...      921
# 23946  BlackBerry names ex-Sybase executive as chief ...      921
# 23947  Production halted at Samsung China supplier am...      921
# 23948  Huawei's H1 revenue up 19 percent year-on-year...      922
# 23949  Allegiant computer outage resolved; 26 flights...      922
# 23950  U.S. judge OKs warrant for Google user's email...      922
# 23952  With 1 million comments, U.S. net neutrality d...      922
# 23953  Auditor of collapsed Spanish company Gowex fre...      922
# 23954  Amazon unveils e-book subscription service wit...      922
# 23955  Google seen best placed for growth as it trans...      922
# 23956  NQ Mobile dismisses independent auditor, share...      922
# 23957  Apple should do more to tackle in-app purchase...      922
# 23958  Smartphone suit against Google plays into riva...      922
# 23959  Google's reshuffle of executives underscores i...      922
# 23960  Next-generation iPhone to enter mass productio...      922
# 23961  Messaging app firm Line Corp filed for US IPO:...      922
# 23962  Fujitsu to form JV with Taiwan's UMC to own, r...      922
# 23963  Apple appoints BlackRock founding partner to b...      922
# 23964  NZ's Chorus makes deal to get paid early for U...      922
# 23965  IBM software sales weaker than expected in sec...      922
#
#                  source                                               link  \
# 8            By Reuters  /news/economy-news/iran-approves-antimoney-lau...
# 9            By Reuters  /news/economy-news/china-house-price-gains-no-...
# 10           By Reuters  /news/economy-news/take-five-be-careful-out-th...
# 11           By Reuters  /news/economy-news/trump-congress-leaders-set-...
# 12           By Reuters  /news/economy-news/feds-mester-rates-near-neut...
# 13           By Reuters  /news/economy-news/feds-powell-pledges-patienc...
# 14           By Reuters  /news/economy-news/yield-curve-not-reliable-us...
# 15           By Reuters  /news/economy-news/chinas-economic-woes-put-us...
# 16           By Reuters  /news/economy-news/trump-claims-trade-talks-wi...
# 17           By Reuters  /news/economy-news/us-economic-growth-likely-t...
# 18           By Reuters  /news/economy-news/brazils-chicago-oldies-aim-...
# 19           By Reuters  /news/economy-news/fed-chair-powell-says-he-wo...
# 20         By Bloomberg  /news/economy-news/powell-says-fed-ready-to-ad...
# 21           By Reuters  /news/economy-news/traders-keep-bets-on-no-fed...
# 22           By Reuters  /news/economy-news/euro-zone-finance-ministers...
# 23           By Reuters  /news/economy-news/uk-local-authority-pension-...
# 24           By Reuters  /news/economy-news/china-cuts-banks-reserve-ra...
# 25           By Reuters  /news/economy-news/china-warnings-signal-trump...
# 26           By Reuters  /news/economy-news/brazils-bolsonaro-may-raise...
# 27     By Investing.com  /news/economy-news/top-5-things-to-know-in-the...
# 28           By Reuters  /news/economy-news/china-and-us-to-hold-trade-...
# 29           By Reuters  /news/economy-news/ecb-rates-to-remain-low-as-...
# 30           By Reuters  /news/economy-news/china-will-cut-banks-reserv...
# 31           By Reuters  /news/economy-news/democrats-to-push-shutdown-...
# 32           By Reuters  /news/economy-news/twoyear-yield-dips-below-ke...
# 33           By Reuters  /news/economy-news/china-approves-new-urban-ra...
# 34           By Reuters  /news/economy-news/powells-plain-english-fed-m...
# 35     By Investing.com  /news/economy-news/chances-of-fed-rate-cut-jum...
# 36           By Reuters  /news/economy-news/end-of-ecb-buys-leaves-ital...
# 37           By Reuters  /news/economy-news/apple-sales-should-pick-up-...
# ...                 ...                                                ...
# 23935        By Reuters  /news/technology-news/netflix's-europe-expansi...
# 23936        By Reuters  /news/technology-news/comcast,-lionsgate-add-m...
# 23937        By Reuters  /news/technology-news/china's-xiaomi-announces...
# 23938        By Reuters  /news/technology-news/fund-managers-unconvince...
# 23939        By Reuters  /news/technology-news/seagate,-avago-subsidiar...
# 23940        By Reuters  /news/technology-news/netflix-profit-more-than...
# 23941        By Reuters  /news/technology-news/talk-on-cracking-interne...
# 23942        By Reuters  /news/technology-news/italy-gives-google-18-mo...
# 23943        By Reuters  /news/technology-news/ex-autonomy-cfo-opposes-...
# 23944        By Reuters  /news/technology-news/payments-startup-stripe-...
# 23945        By Reuters  /news/technology-news/israel's-mobileye-starts...
# 23946        By Reuters  /news/technology-news/blackberry-names-ex-syba...
# 23947        By Reuters  /news/technology-news/production-halted-at-sam...
# 23948        By Reuters  /news/technology-news/huawei's-h1-revenue-up-1...
# 23949        By Reuters  /news/technology-news/allegiant-computer-outag...
# 23950        By Reuters  /news/technology-news/u.s.-judge-oks-warrant-f...
# 23952        By Reuters  /news/technology-news/with-1-million-comments,...
# 23953        By Reuters  /news/technology-news/auditor-of-collapsed-spa...
# 23954        By Reuters  /news/technology-news/amazon-unveils-e-book-su...
# 23955        By Reuters  /news/technology-news/google-seen-best-placed-...
# 23956        By Reuters  /news/technology-news/nq-mobile-dismisses-inde...
# 23957        By Reuters  /news/technology-news/apple-should-do-more-to-...
# 23958        By Reuters  /news/technology-news/smartphone-suit-against-...
# 23959        By Reuters  /news/technology-news/google's-reshuffle-of-ex...
# 23960        By Reuters  /news/technology-news/next-generation-iphone-t...
# 23961        By Reuters  /news/technology-news/messaging-app-firm-line-...
# 23962        By Reuters  /news/technology-news/fujitsu-to-form-jv-with-...
# 23963        By Reuters  /news/technology-news/apple-appoints-blackrock...
# 23964        By Reuters  /news/technology-news/nz's-chorus-makes-deal-t...
# 23965        By Reuters  /news/technology-news/ibm-beats-revenue-estima...
#
#                   date                                               news  \
# 8       - Jan 05, 2019   LONDON (Reuters) - A powerful Iranian council...
# 9       - Jan 05, 2019   SHANGHAI (Reuters) - A rising trend in proper...
# 10      - Jan 04, 2019   (Reuters) - Following are five big themes lik...
# 11      - Jan 04, 2019   By Richard Cowan and Jeff Mason WASHINGTON (R...
# 12      - Jan 04, 2019   By Howard Schneider ATLANTA (Reuters) - From ...
# 13      - Jan 04, 2019   By Howard Schneider and Jonathan Spicer ATLAN...
# 14      - Jan 04, 2019   WASHINGTON (Reuters) - The U.S. Treasury yiel...
# 15      - Jan 04, 2019   WASHINGTON (Reuters) - President Donald Trump...
# 16      - Jan 04, 2019   WASHINGTON (Reuters) - U.S. President Donald ...
# 17      - Jan 04, 2019   By Jason Lange BALTIMORE (Reuters) - The U.S....
# 18      - Jan 04, 2019   By Anthony Boadle BRASILIA(Reuters) - Brazil&...
# 19      - Jan 04, 2019   ATLANTA (Reuters) - Federal Reserve Chairman ...
# 20      - Jan 04, 2019   (Bloomberg) -- Federal Reserve Chairman Jerom...
# 21      - Jan 04, 2019   By Ann Saphir (Reuters) - A government report...
# 22      - Jan 04, 2019   BRUSSELS (Reuters) - Euro zone finance minist...
# 23      - Jan 04, 2019   By Maiya Keidan and Carolyn Cohn LONDON (Reut...
# 24      - Jan 04, 2019   By Kevin Yao and Lusha Zhang BEIJING (Reuters...
# 25      - Jan 04, 2019   By Howard Schneider and Jonathan Spicer ATLAN...
# 26      - Jan 04, 2019   SAO PAULO (Reuters) - Brazil&aposs new Presid...
# 27      - Jan 04, 2019   Investing.com - Here are the top five things ...
# 28      - Jan 04, 2019   BEIJING (Reuters) - China and the United Stat...
# 29      - Jan 04, 2019   PARIS (Reuters) - The European Central Bank&a...
# 30      - Jan 04, 2019   BEIJING (Reuters) - China will cut banks&apos...
# 31      - Jan 03, 2019   By Amanda Becker and Richard Cowan WASHINGTON...
# 32      - Jan 03, 2019   By Kate Duguid NEW YORK (Reuters) - The U.S. ...
# 33      - Jan 03, 2019   SHANGHAI (Reuters) - China's state planner sa...
# 34      - Jan 03, 2019   By Howard Schneider ATLANTA (Reuters) - Fed C...
# 35      - Jan 03, 2019   Investing.com - Apple’s profit warning isn’t ...
# 36      - Jan 03, 2019   FRANKFURT (Reuters) - The end of the European...
# 37      - Jan 03, 2019   WASHINGTON (Reuters) - A sharp drop in Chines...
# ...                ...                                                ...
# 23935   - Jul 22, 2014   (Reuters) - Netflix Inc's planned expansion i...
# 23936   - Jul 22, 2014   (Reuters) - Lions Gate Entertainment Corp wil...
# 23937   - Jul 22, 2014   BEIJING (Reuters) - China's Xiaomi unveiled o...
# 23938   - Jul 21, 2014   By David Randall and Edwin Chan NEW YORK/SAN ...
# 23939   - Jul 21, 2014   WASHINGTON (Reuters) - Avago Technologies Ltd...
# 23940   - Jul 21, 2014   LOS ANGELES (Reuters) - Netflix Inc's quarter...
# 23941   - Jul 21, 2014   By Joseph Menn  SAN FRANCISCO (Reuters) - A h...
# 23942   - Jul 21, 2014   By Danilo Masoni MILAN (Reuters) - Italy's da...
# 23943   - Jul 21, 2014   (Reuters) - A former chief financial officer ...
# 23944   - Jul 21, 2014   SAN FRANCISCO (Reuters) - Stripe launched in ...
# 23945   - Jul 21, 2014   JERUSALEM (Reuters) - Mobileye N.V., which ma...
# 23946   - Jul 21, 2014   TORONTO (Reuters) - BlackBerry Limited (TO:BB...
# 23947   - Jul 21, 2014   By James Pomfret  CHASHAN China (Reuters) - P...
# 23948   - Jul 20, 2014   TAIPEI (Reuters) - Huawei Technologies Co Ltd...
# 23949   - Jul 18, 2014   (Reuters) - Allegiant Travel Co, the parent o...
# 23950   - Jul 18, 2014    By Joseph Ax  NEW YORK (Reuters) - A federal...
# 23952   - Jul 18, 2014    By Alina Selyukh  WASHINGTON (Reuters) - U.S...
# 23953   - Jul 18, 2014   MADRID (Reuters) - The auditor of collapsed w...
# 23954   - Jul 18, 2014   (Reuters) - Amazon.com Inc on Friday unveiled...
# 23955   - Jul 18, 2014   (Reuters) - Google Inc (O:GOOGL) is the best ...
# 23956   - Jul 18, 2014   (Reuters) - NQ Mobile Inc, a Chinese mobile s...
# 23957   - Jul 18, 2014   By Julia Fioretti BRUSSELS (Reuters) - Apple ...
# 23958   - Jul 18, 2014   By Dan Levine SAN FRANCISCO (Reuters) - A U.S...
# 23959   - Jul 17, 2014   By Alexei Oreskovic SAN FRANCISCO (Reuters) -...
# 23960   - Jul 17, 2014   TAIPEI (Reuters) - Taiwan's Hon Hai Precision...
# 23961   - Jul 17, 2014   SEOUL (Reuters) - Japan-based social messagin...
# 23962   - Jul 17, 2014    TOKYO (Reuters) - Fujitsu Ltd plans to form ...
# 23963   - Jul 17, 2014   (Reuters) - Apple Inc said Susan Wagner, foun...
# 23964   - Jul 17, 2014   WELLINGTON (Reuters) - New Zealand telecommun...
# 23965   - Jul 17, 2014    By Marina Lopes  WASHINGTON (Reuters) - Inte...
#
#          category
# 8         economy
# 9         economy
# 10        economy
# 11        economy
# 12        economy
# 13        economy
# 14        economy
# 15        economy
# 16        economy
# 17        economy
# 18        economy
# 19        economy
# 20        economy
# 21        economy
# 22        economy
# 23        economy
# 24        economy
# 25        economy
# 26        economy
# 27        economy
# 28        economy
# 29        economy
# 30        economy
# 31        economy
# 32        economy
# 33        economy
# 34        economy
# 35        economy
# 36        economy
# 37        economy
# ...           ...
# 23935  technology
# 23936  technology
# 23937  technology
# 23938  technology
# 23939  technology
# 23940  technology
# 23941  technology
# 23942  technology
# 23943  technology
# 23944  technology
# 23945  technology
# 23946  technology
# 23947  technology
# 23948  technology
# 23949  technology
# 23950  technology
# 23952  technology
# 23953  technology
# 23954  technology
# 23955  technology
# 23956  technology
# 23957  technology
# 23958  technology
# 23959  technology
# 23960  technology
# 23961  technology
# 23962  technology
# 23963  technology
# 23964  technology
# 23965  technology
#
# [216299 rows x 7 columns]

# %%
import datetime as dt
all_news['date'] = all_news['date'].map(lambda row: pd.to_datetime(doubledecode(row,True), format = '%b %d, %Y',errors = 'coerce'))
all_news = all_news.dropna()
all_news['date'] = all_news['date'].map(lambda row: pd.to_datetime(row.strftime('%d-%m-%Y'), format = '%d-%m-%Y'))
all_news = all_news.sort_values(by='date',ascending=False)
display(all_news)
